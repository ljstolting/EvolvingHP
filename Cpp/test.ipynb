# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
traj = np.loadtxt('./No Timing Requirements/13/pylorictrajectory.dat')

# %%
plt.rcParams['figure.figsize'] = (15,3)
for i in range(len(traj[0])):
    plt.plot(traj[:,i])
