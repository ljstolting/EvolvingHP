# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as m

# %%
num_runs = 500
state_int = 50
param_int = 10
num_param_trajs = int(num_runs/param_int)

dur = 50000
dt = .005*5
time = np.arange(0,dur+dt,dt)
print(len(time))
# Out:
# 2000001

# %%
# trajs_bad = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/80/1/biastrack.dat").reshape(num_param_trajs,len(time),2)
# ics_bad = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/80/1/ics.dat").reshape(num_runs,2,15)[:,:,3:6:2]
# trajs_good = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/80/2/biastrack.dat").reshape(num_param_trajs,len(time),2)
# ics_good = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/80/2/ics.dat").reshape(num_runs,2,15)[:,:,3:6:2]
trajs_mixed = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/80/3/biastrack.dat").reshape(num_param_trajs,len(time),2)
ics_mixed = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/80/3/ics.dat").reshape(num_runs,2,15)[:,:,3:6:2]

# %%
pyloric = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/80/pyloricslice_highres.dat").swapaxes(0,1)
res = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/80/res_highres.dat")
par1res = np.arange(res[0,0],res[0,1],res[0,2])
par2res= np.arange(res[1,0],res[1,1],res[1,2])
plt.contour(par1res,par2res,pyloric,levels=[.3])

# %%
print(trajs_mixed[0])
# Out:
# [[ 1.82431 15.3561 ]
#  [ 1.82431 15.3561 ]
#  [ 1.82431 15.3561 ]
#  ...
#  [-6.30426  7.41003]
#  [-6.30426  7.41003]
#  [-6.30426  7.41003]]

# %%
plt.scatter(ics_mixed[:,0,0],ics_mixed[:,0,1],c='k',s=2)
plt.scatter(ics_mixed[:,1,0],ics_mixed[:,1,1],c='r')
plt.contour(par1res,par2res,pyloric,levels=[.3],colors='g')
for i in range(num_param_trajs):
    plt.plot(trajs_mixed[i,:,0],trajs_mixed[i,:,1],c='k',alpha=.5)
plt.xlim(-20,20)
plt.ylim(-20,20)
plt.show()

# %%
trajs
# Out:
# 20000000

# %%
num_trajs = 6
stepsize = 0.005
stepinterval = 5
plasticdur = 100000
time = np.arange(0,plasticdur,stepsize*stepinterval)

trajs = trajs.reshape(num_trajs,len(time),2)

# %%
for i in range(len(trajs)):
    plt.plot(trajs[i,:,0],trajs[i,:,1])
plt.show()

# %%
backup = 20000
for i in range(len(trajs)):
    plt.plot(trajs[i,-backup:,0],trajs[i,-backup:,1],color='r')
plt.show()

# %%
pyloric = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/81/pyloricslice.dat")
par1res = np.arange(-16,16.01,0.1)
par2res = par1res

# %%
plt.pcolormesh(par1res,par2res,pyloric,norm=m.colors.PowerNorm(gamma=0.15))
for i in [2]:
    plt.plot(trajs[i,:,0],trajs[i,:,1],color='r')

# %%
HPagnostic = np.loadtxt("./Specifically Evolved HP mechanisms/Every Circuit/81/HPAgnosticAverage.dat").reshape((321,321,3))

# %%
plt.pcolormesh(par1res,par2res,HPagnostic[:,:,0])
plt.colorbar()
plt.contour(par1res,par2res,HPagnostic[:,:,0],levels=[.2],colors='r')
plt.contour(par1res,par2res,HPagnostic[:,:,2],levels=[.5],colors='orange')
plt.contour(par1res,par2res,pyloric,levels=[.3],colors='w')
# plt.plot(trajs[0,:,0],trajs[0,:,1])
# plt.plot(trajs[4,:,0],trajs[4,:,1])
# plt.plot(trajs[3,:,0],trajs[3,:,1])
plt.show()
