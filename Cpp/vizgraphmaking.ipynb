# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter([-10,-10,-10,0,0,0,10,10,10],[-10,0,10,-10,0,10,-10,0,10])
plt.xlabel(r'$\theta_{LB}$')
plt.ylabel(r'$\theta_{PD}$')
plt.ylim(-16,16)
plt.xlim(-16,16)
plt.rcParams['font.size'] = 36
plt.show()
